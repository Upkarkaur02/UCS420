# %%
#Assignment 2.1
#Add three numbers
a = 10
b = 200
c = 40
d = a + b + c
print(a, "+", b, "+", c, " --> ", d)
# Out:
# 10 + 200 + 40  -->  250

# %%
#Concatinate three Strings
a = "Upkar"
b = " Kaur"
c = " pawar"
d = a + b + c
print(a, "+", b, "+", c, " --> ", d)
# Out:
# Upkar +  Kaur +  pawar  -->  Upkar Kaur pawar
